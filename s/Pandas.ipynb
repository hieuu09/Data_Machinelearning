# %%
import pandas as pd
#heade =0 lay dong dau tien  lam header, sep phan chia dau
# not khoang trang
df = pd.read_csv('https://raw.githubusercontent.com/phamdinhkhanh/datasets/master/insurance.csv', header=0, sep=',')
print(df.shape) # kich thuoc hang cot, sep phan chia theo dau ,
df.sample(5)
# charge trung vi nho hon trung binh
# Out:
# (1338, 7)
#      age     sex     bmi  children smoker     region      charges
# 548   25  female  28.595         0     no  northeast   3213.62205
# 389   24  female  30.210         3     no  northwest   4618.07990
# 775   51    male  33.330         3     no  southeast  10560.49170
# 189   29  female  32.110         2     no  northwest   4922.91590
# 191   36  female  26.200         0     no  southwest   4883.86600

# %%
df.info()
# non_null tranh mis du lieu
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
list(df.columns)# in ra ten cot thong ke kieu so
#dien ta kieu du liwu
df.describe() # mean trung binh thong ke nguyen kia so
#std do lech chuan
# thong ke chuoi
# neu muon dien a all
df.describe(include='all') # thong ke them ca string top so xuat ien nhieu nhat
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
# loc vs iloc index cua no hien row colums
df.head()# no return 5 hang dau tien
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.loc[(df.age==64) | (df.children==5)] # loc hang nao
# hoac co dieu kien va , and , hoac cos tuoi = 64 of childen =5
# Out:
#       age     sex     bmi  children smoker     region      charges
# 32     19  female  28.600         5     no  southwest   4687.79700
# 62     64    male  24.700         1     no  northwest  30166.61817
# 71     31    male  28.500         5     no  northeast   6799.45800
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 166    20  female  37.000         5     no  southwest   4830.63000
# 199    64  female  39.330         0     no  northeast  14901.51670
# 328    64  female  33.800         1    yes  southwest  47928.03000
# 335    64    male  34.500         0     no  southwest  13822.80300
# 378    64  female  30.115         3     no  northwest  16455.70785
# 398    64    male  25.600         2     no  southwest  14988.43200
# 402    64  female  32.965         0     no  northwest  14692.66935
# 413    25    male  23.900         5     no  southwest   5080.09600
# 418    64    male  39.160         1     no  southeast  14418.28040
# ...

# %%
df.loc[(df.age==64) | (df.children==5), ['age', 'sex', 'smoker']] # loc hang nao
# hoac co dieu kien va , and , hoac cos tuoi = 64 of childen =5 # chi hien cac dong dc lua cho de hien
# Out:
#       age     sex smoker
# 32     19  female     no
# 62     64    male     no
# 71     31    male     no
# 94     64  female    yes
# 166    20  female     no
# 199    64  female     no
# 328    64  female    yes
# 335    64    male     no
# 378    64  female     no
# 398    64    male     no
# 402    64  female     no
# 413    25    male     no
# 418    64    male     no
# 420    64    male    yes
# 425    45    male     no
# 438    52  female     no
# 534    64    male     no
# 568    49  female     no
# 603    64  female     no
# 635    64    male     no
# 640    33    male     no
# 664    64  female    yes
# 752    64    male     no
# 768    64  female     no
# 801    64  female     no
# 825    64  female     no
# 877    33    male     no
# 890    64  female    yes
# 932    46    male     no
# 937    39  female     no
# 969    39  female     no
# 984    20    male     no
# 1051   64    male     no
# 1085   39  female    yes
# 1116   41    male     no
# 1130   39  female     no
# ...

# %%
# lua cho index location
# cho cot hang so vi bat dau bang 0 thif 9 + 1 thi vi tri so 10
df.iloc[[9]]
# Out:
#    age     sex    bmi  children smoker     region      charges
# 9   60  female  25.84         0     no  northwest  28923.13692

# %%
# lay si index so 3 den so 10
df.iloc[3:11]
# Out:
#     age     sex     bmi  children smoker     region      charges
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080

# %%
df.iloc[3:5, :-1]
# Out:
#    age   sex     bmi  children smoker     region
# 3   33  male  22.705         0     no  northwest
# 4   32  male  28.880         0     no  northwest

# %%
# chec kieu due lie
df.age.dtype # kieu du lieu
# Out:
# dtype('int64')

# %%
# apply muon xua do la kieu so muon xoa so do la
# df.age.apply(lambda x:x.replace('$', ''))
# cuyen xong so do la chuyen sang float
df.age.appy(lambda x:x.float(replace('$', ''))) # chuyen doi so x sau khi xoa so thuc

# %%
# tao columns moi
df["to_age"]= df["age"]+10

# %%
# tinh tong so tuoi
tongtuoi =df["age"].sum()
print('Tong tuoi la ',tongtuoi)
# Out:
# Tong tuoi la  52459

# %%
# group nu
tuoi=df.groupby("sex")["age"].sum() # gioi tinh dc tinh tong tuoi la
print(tuoi)
# Out:
# sex
# female    26151
# male      26308
# Name: age, dtype: int64

# %%
# sap xep so tupo
tuoi.sort_values(ascending=False)
# Out:
# sex
# male      26308
# female    26151
# Name: age, dtype: int64

# %%
#lay gia tri duy nhat
df.sex.value_counts()#.count()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
# lay gia tri khac nhau
df.sex.nunique()
# Out:
# 2
